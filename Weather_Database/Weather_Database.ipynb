# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes into a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, the we will add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficint count
print(len(cities))
# Out:
# 759

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date,
                         "Description": city_desc})
        
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete
print("-------------------------------")
print("Data Retrieval Complete        ")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | poplar bluff
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | cap malheureux
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | lebanon
# Processing Record 8 of Set 1 | hede
# Processing Record 9 of Set 1 | chuy
# Processing Record 10 of Set 1 | fairbanks
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 1 | iskateley
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | odweyne
# Processing Record 24 of Set 1 | tombouctou
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | pokrovsk
# Processing Record 27 of Set 1 | ilulissat
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | norman wells
# Processing Record 30 of Set 1 | san-pedro
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | longyearbyen
# Processing Record 33 of Set 1 | kailua
# Processing Record 34 of Set 1 | los lunas
# Processing Record 35 of Set 1 | preobrazheniye
# Processing Record 36 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | ahmadpur east
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | lorengau
# Processing Record 45 of Set 1 | hambantota
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | kavaratti
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | gonzalez
# Processing Record 50 of Set 1 | narsaq
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | iqaluit
# Processing Record 3 of Set 2 | pimentel
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | namibe
# Processing Record 7 of Set 2 | inverell
# Processing Record 8 of Set 2 | nemuro
# Processing Record 9 of Set 2 | lafia
# Processing Record 10 of Set 2 | leningradskiy
# Processing Record 11 of Set 2 | bairiki
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | husavik
# Processing Record 14 of Set 2 | tautira
# Processing Record 15 of Set 2 | la ferte-bernard
# Processing Record 16 of Set 2 | ahipara
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | carauari
# Processing Record 20 of Set 2 | abeche
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | keti bandar
# Processing Record 23 of Set 2 | gat
# Processing Record 24 of Set 2 | mweka
# Processing Record 25 of Set 2 | new norfolk
# Processing Record 26 of Set 2 | san jose
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | athabasca
# Processing Record 30 of Set 2 | nakhon thai
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | takapau
# Processing Record 33 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 2 | camopi
# Processing Record 35 of Set 2 | birao
# Processing Record 36 of Set 2 | mikkeli
# Processing Record 37 of Set 2 | chiredzi
# Processing Record 38 of Set 2 | kapaa
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | marfino
# Processing Record 41 of Set 2 | severo-kurilsk
# Processing Record 42 of Set 2 | port moresby
# Processing Record 43 of Set 2 | agidel
# Processing Record 44 of Set 2 | akhmeta
# Processing Record 45 of Set 2 | arcata
# Processing Record 46 of Set 2 | matay
# Processing Record 47 of Set 2 | carnarvon
# Processing Record 48 of Set 2 | port macquarie
# Processing Record 49 of Set 2 | isangel
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | cabo san lucas
# Processing Record 2 of Set 3 | obo
# Processing Record 3 of Set 3 | nantucket
# Processing Record 4 of Set 3 | bow island
# Processing Record 5 of Set 3 | council bluffs
# Processing Record 6 of Set 3 | alofi
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | inuvik
# Processing Record 10 of Set 3 | cape town
# Processing Record 11 of Set 3 | faanui
# Processing Record 12 of Set 3 | vostok
# Processing Record 13 of Set 3 | barcelos
# Processing Record 14 of Set 3 | hwange
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | lokosovo
# Processing Record 17 of Set 3 | luanda
# Processing Record 18 of Set 3 | maun
# Processing Record 19 of Set 3 | prainha
# Processing Record 20 of Set 3 | lavrentiya
# Processing Record 21 of Set 3 | bluff
# Processing Record 22 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 3 | lagoa
# Processing Record 24 of Set 3 | guerrero negro
# Processing Record 25 of Set 3 | port loko
# Processing Record 26 of Set 3 | shikhany
# Processing Record 27 of Set 3 | tiksi
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | kaitangata
# Processing Record 30 of Set 3 | santa maria
# Processing Record 31 of Set 3 | talnakh
# Processing Record 32 of Set 3 | bubaque
# Processing Record 33 of Set 3 | scottsbluff
# Processing Record 34 of Set 3 | copiapo
# Processing Record 35 of Set 3 | seymchan
# Processing Record 36 of Set 3 | asyut
# Processing Record 37 of Set 3 | bredasdorp
# Processing Record 38 of Set 3 | mar del plata
# Processing Record 39 of Set 3 | butaritari
# Processing Record 40 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 3 | manicore
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | cherskiy
# Processing Record 45 of Set 3 | jiuquan
# Processing Record 46 of Set 3 | boulder city
# Processing Record 47 of Set 3 | atambua
# Processing Record 48 of Set 3 | itarema
# Processing Record 49 of Set 3 | viedma
# Processing Record 50 of Set 3 | dandong
# Processing Record 1 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 4 | lakshmipur
# Processing Record 3 of Set 4 | kumluca
# Processing Record 4 of Set 4 | turiacu
# Processing Record 5 of Set 4 | hobyo
# Processing Record 6 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 4 | provideniya
# Processing Record 8 of Set 4 | noyabrsk
# Processing Record 9 of Set 4 | kavieng
# Processing Record 10 of Set 4 | mayumba
# Processing Record 11 of Set 4 | susanville
# Processing Record 12 of Set 4 | ribeira grande
# Processing Record 13 of Set 4 | katha
# City not found. Skipping...
# Processing Record 14 of Set 4 | nouadhibou
# Processing Record 15 of Set 4 | duki
# Processing Record 16 of Set 4 | goderich
# Processing Record 17 of Set 4 | de aar
# Processing Record 18 of Set 4 | iberia
# Processing Record 19 of Set 4 | nome
# Processing Record 20 of Set 4 | talaya
# Processing Record 21 of Set 4 | shimizu
# Processing Record 22 of Set 4 | puerto madryn
# Processing Record 23 of Set 4 | kulhudhuffushi
# Processing Record 24 of Set 4 | manta
# Processing Record 25 of Set 4 | baley
# Processing Record 26 of Set 4 | alice
# Processing Record 27 of Set 4 | curillo
# Processing Record 28 of Set 4 | sao gabriel
# Processing Record 29 of Set 4 | saint-georges
# Processing Record 30 of Set 4 | alihe
# Processing Record 31 of Set 4 | amarante
# Processing Record 32 of Set 4 | misantla
# Processing Record 33 of Set 4 | tutoia
# Processing Record 34 of Set 4 | makakilo city
# Processing Record 35 of Set 4 | seara
# Processing Record 36 of Set 4 | gushikawa
# Processing Record 37 of Set 4 | samarai
# Processing Record 38 of Set 4 | zhangjiakou
# Processing Record 39 of Set 4 | dingle
# Processing Record 40 of Set 4 | aswan
# Processing Record 41 of Set 4 | broome
# Processing Record 42 of Set 4 | mataram
# Processing Record 43 of Set 4 | san jeronimo
# Processing Record 44 of Set 4 | oistins
# Processing Record 45 of Set 4 | yar-sale
# Processing Record 46 of Set 4 | lata
# Processing Record 47 of Set 4 | tiarei
# Processing Record 48 of Set 4 | laguna
# Processing Record 49 of Set 4 | saldanha
# Processing Record 50 of Set 4 | dickinson
# Processing Record 1 of Set 5 | port hedland
# Processing Record 2 of Set 5 | leh
# Processing Record 3 of Set 5 | someshwar
# Processing Record 4 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 5 | cabedelo
# Processing Record 6 of Set 5 | ndele
# Processing Record 7 of Set 5 | olafsvik
# Processing Record 8 of Set 5 | belyy yar
# Processing Record 9 of Set 5 | skoczow
# Processing Record 10 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 11 of Set 5 | solok
# Processing Record 12 of Set 5 | chake chake
# Processing Record 13 of Set 5 | thanh hoa
# Processing Record 14 of Set 5 | englewood
# Processing Record 15 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 5 | senanga
# Processing Record 17 of Set 5 | valparaiso
# Processing Record 18 of Set 5 | tasiilaq
# Processing Record 19 of Set 5 | neftcala
# Processing Record 20 of Set 5 | mayakonda
# Processing Record 21 of Set 5 | puerto ayacucho
# Processing Record 22 of Set 5 | tilichiki
# Processing Record 23 of Set 5 | atar
# Processing Record 24 of Set 5 | bisho
# Processing Record 25 of Set 5 | marck
# Processing Record 26 of Set 5 | cururupu
# Processing Record 27 of Set 5 | mwinilunga
# Processing Record 28 of Set 5 | nurota
# Processing Record 29 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 5 | ponta do sol
# Processing Record 31 of Set 5 | xichang
# Processing Record 32 of Set 5 | mahebourg
# Processing Record 33 of Set 5 | kinna
# Processing Record 34 of Set 5 | ballina
# Processing Record 35 of Set 5 | comodoro rivadavia
# Processing Record 36 of Set 5 | zapresic
# Processing Record 37 of Set 5 | alyangula
# Processing Record 38 of Set 5 | khatanga
# Processing Record 39 of Set 5 | mantua
# Processing Record 40 of Set 5 | ilinskiy
# Processing Record 41 of Set 5 | henties bay
# Processing Record 42 of Set 5 | nelson bay
# Processing Record 43 of Set 5 | tianpeng
# Processing Record 44 of Set 5 | asau
# Processing Record 45 of Set 5 | parainen
# Processing Record 46 of Set 5 | moron
# Processing Record 47 of Set 5 | bure
# Processing Record 48 of Set 5 | pevek
# Processing Record 49 of Set 5 | george
# Processing Record 50 of Set 5 | sao joao da barra
# Processing Record 1 of Set 6 | mangile
# City not found. Skipping...
# Processing Record 2 of Set 6 | tecoanapa
# Processing Record 3 of Set 6 | okhotsk
# Processing Record 4 of Set 6 | umm lajj
# Processing Record 5 of Set 6 | teguise
# Processing Record 6 of Set 6 | ambilobe
# Processing Record 7 of Set 6 | east london
# Processing Record 8 of Set 6 | musoma
# Processing Record 9 of Set 6 | raudeberg
# Processing Record 10 of Set 6 | airai
# Processing Record 11 of Set 6 | bambous virieux
# Processing Record 12 of Set 6 | mawlaik
# Processing Record 13 of Set 6 | alto araguaia
# Processing Record 14 of Set 6 | del rio
# Processing Record 15 of Set 6 | volksrust
# Processing Record 16 of Set 6 | saskylakh
# Processing Record 17 of Set 6 | kununurra
# Processing Record 18 of Set 6 | oranjemund
# Processing Record 19 of Set 6 | ulety
# Processing Record 20 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 6 | simao
# Processing Record 22 of Set 6 | llanes
# Processing Record 23 of Set 6 | northam
# Processing Record 24 of Set 6 | pangody
# Processing Record 25 of Set 6 | klaksvik
# Processing Record 26 of Set 6 | haines junction
# Processing Record 27 of Set 6 | kimberley
# Processing Record 28 of Set 6 | eyl
# Processing Record 29 of Set 6 | caravelas
# Processing Record 30 of Set 6 | chissamba
# Processing Record 31 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 6 | kieta
# Processing Record 33 of Set 6 | hasaki
# Processing Record 34 of Set 6 | ronde
# Processing Record 35 of Set 6 | upernavik
# Processing Record 36 of Set 6 | nyurba
# Processing Record 37 of Set 6 | anastacio
# Processing Record 38 of Set 6 | galle
# Processing Record 39 of Set 6 | high prairie
# Processing Record 40 of Set 6 | vestmannaeyjar
# Processing Record 41 of Set 6 | sirjan
# Processing Record 42 of Set 6 | emerald
# Processing Record 43 of Set 6 | port blair
# Processing Record 44 of Set 6 | lukovetskiy
# Processing Record 45 of Set 6 | elk point
# Processing Record 46 of Set 6 | porto de moz
# Processing Record 47 of Set 6 | sampit
# Processing Record 48 of Set 6 | wenatchee
# Processing Record 49 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 6 | pochutla
# Processing Record 1 of Set 7 | jinchang
# Processing Record 2 of Set 7 | mogadishu
# Processing Record 3 of Set 7 | sergeyevka
# Processing Record 4 of Set 7 | akyab
# Processing Record 5 of Set 7 | pisco
# Processing Record 6 of Set 7 | cayenne
# Processing Record 7 of Set 7 | egvekinot
# Processing Record 8 of Set 7 | riyadh
# Processing Record 9 of Set 7 | tamale
# Processing Record 10 of Set 7 | souillac
# Processing Record 11 of Set 7 | san quintin
# Processing Record 12 of Set 7 | saint-pierre
# Processing Record 13 of Set 7 | matara
# Processing Record 14 of Set 7 | buckeye
# Processing Record 15 of Set 7 | lasalgaon
# Processing Record 16 of Set 7 | kinanah
# City not found. Skipping...
# Processing Record 17 of Set 7 | machico
# Processing Record 18 of Set 7 | salym
# Processing Record 19 of Set 7 | temir
# Processing Record 20 of Set 7 | beatrice
# Processing Record 21 of Set 7 | broken hill
# Processing Record 22 of Set 7 | katobu
# Processing Record 23 of Set 7 | coquimbo
# Processing Record 24 of Set 7 | botou
# Processing Record 25 of Set 7 | labuhan
# Processing Record 26 of Set 7 | nioro
# Processing Record 27 of Set 7 | pendleton
# Processing Record 28 of Set 7 | azanka
# Processing Record 29 of Set 7 | balikpapan
# Processing Record 30 of Set 7 | batagay-alyta
# Processing Record 31 of Set 7 | the valley
# Processing Record 32 of Set 7 | safaga
# Processing Record 33 of Set 7 | los llanos de aridane
# Processing Record 34 of Set 7 | port lincoln
# Processing Record 35 of Set 7 | ternate
# Processing Record 36 of Set 7 | maceio
# Processing Record 37 of Set 7 | pitkyaranta
# Processing Record 38 of Set 7 | bengkulu
# Processing Record 39 of Set 7 | gambela
# Processing Record 40 of Set 7 | garowe
# Processing Record 41 of Set 7 | ketchikan
# Processing Record 42 of Set 7 | gurgentepe
# Processing Record 43 of Set 7 | champerico
# Processing Record 44 of Set 7 | katsuura
# Processing Record 45 of Set 7 | avera
# Processing Record 46 of Set 7 | tomatlan
# Processing Record 47 of Set 7 | kokkola
# Processing Record 48 of Set 7 | voi
# Processing Record 49 of Set 7 | marovoay
# Processing Record 50 of Set 7 | ribnitz-damgarten
# Processing Record 1 of Set 8 | boa vista
# Processing Record 2 of Set 8 | eenhana
# Processing Record 3 of Set 8 | marystown
# Processing Record 4 of Set 8 | progreso
# Processing Record 5 of Set 8 | berbera
# Processing Record 6 of Set 8 | wasilla
# Processing Record 7 of Set 8 | sobolevo
# Processing Record 8 of Set 8 | puerto leguizamo
# Processing Record 9 of Set 8 | christchurch
# Processing Record 10 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 8 | bambanglipuro
# Processing Record 12 of Set 8 | mount gambier
# Processing Record 13 of Set 8 | kruisfontein
# Processing Record 14 of Set 8 | alice springs
# Processing Record 15 of Set 8 | nagato
# Processing Record 16 of Set 8 | kholm
# Processing Record 17 of Set 8 | deulgaon raja
# Processing Record 18 of Set 8 | mount isa
# Processing Record 19 of Set 8 | sfantu gheorghe
# Processing Record 20 of Set 8 | marzuq
# Processing Record 21 of Set 8 | bajil
# Processing Record 22 of Set 8 | cervo
# Processing Record 23 of Set 8 | antofagasta
# Processing Record 24 of Set 8 | zhuanghe
# Processing Record 25 of Set 8 | hamilton
# Processing Record 26 of Set 8 | alta floresta
# Processing Record 27 of Set 8 | sitka
# Processing Record 28 of Set 8 | beringovskiy
# Processing Record 29 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 30 of Set 8 | polovinnoye
# Processing Record 31 of Set 8 | samfya
# Processing Record 32 of Set 8 | sorland
# Processing Record 33 of Set 8 | kyra
# Processing Record 34 of Set 8 | constitucion
# Processing Record 35 of Set 8 | puerto quijarro
# Processing Record 36 of Set 8 | houston
# Processing Record 37 of Set 8 | clyde river
# Processing Record 38 of Set 8 | ca mau
# Processing Record 39 of Set 8 | enterprise
# Processing Record 40 of Set 8 | carutapera
# Processing Record 41 of Set 8 | grand gaube
# Processing Record 42 of Set 8 | umm kaddadah
# Processing Record 43 of Set 8 | jaitaran
# Processing Record 44 of Set 8 | caorle
# Processing Record 45 of Set 8 | sapernoye
# Processing Record 46 of Set 8 | khuzdar
# Processing Record 47 of Set 8 | ixtapa
# Processing Record 48 of Set 8 | grande-riviere
# City not found. Skipping...
# Processing Record 49 of Set 8 | surin
# Processing Record 50 of Set 8 | nalut
# Processing Record 1 of Set 9 | viseu
# Processing Record 2 of Set 9 | dubai
# Processing Record 3 of Set 9 | karratha
# Processing Record 4 of Set 9 | saint-augustin
# Processing Record 5 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 6 of Set 9 | auray
# Processing Record 7 of Set 9 | srednekolymsk
# Processing Record 8 of Set 9 | roald
# Processing Record 9 of Set 9 | hofn
# Processing Record 10 of Set 9 | buala
# Processing Record 11 of Set 9 | turayf
# Processing Record 12 of Set 9 | ruwi
# Processing Record 13 of Set 9 | geraldton
# Processing Record 14 of Set 9 | acapulco
# Processing Record 15 of Set 9 | hirara
# Processing Record 16 of Set 9 | jalu
# Processing Record 17 of Set 9 | shimanovsk
# Processing Record 18 of Set 9 | sept-iles
# Processing Record 19 of Set 9 | liberal
# Processing Record 20 of Set 9 | maues
# Processing Record 21 of Set 9 | ampanihy
# Processing Record 22 of Set 9 | mahajanga
# Processing Record 23 of Set 9 | senmonorom
# City not found. Skipping...
# Processing Record 24 of Set 9 | perigueux
# Processing Record 25 of Set 9 | north bend
# Processing Record 26 of Set 9 | boueni
# Processing Record 27 of Set 9 | yulara
# Processing Record 28 of Set 9 | hatillo
# Processing Record 29 of Set 9 | scarborough
# Processing Record 30 of Set 9 | toul
# Processing Record 31 of Set 9 | pocone
# Processing Record 32 of Set 9 | chicama
# Processing Record 33 of Set 9 | bonavista
# Processing Record 34 of Set 9 | nago
# Processing Record 35 of Set 9 | zhigansk
# Processing Record 36 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 9 | mastung
# Processing Record 38 of Set 9 | kosa
# Processing Record 39 of Set 9 | tres barras
# Processing Record 40 of Set 9 | poum
# Processing Record 41 of Set 9 | san patricio
# Processing Record 42 of Set 9 | vao
# Processing Record 43 of Set 9 | bestobe
# Processing Record 44 of Set 9 | komsomolskiy
# Processing Record 45 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 46 of Set 9 | evanston
# Processing Record 47 of Set 9 | mutare
# Processing Record 48 of Set 9 | praia da vitoria
# Processing Record 49 of Set 9 | pacific grove
# Processing Record 50 of Set 9 | nanhai
# Processing Record 1 of Set 10 | shu
# Processing Record 2 of Set 10 | hoquiam
# Processing Record 3 of Set 10 | vanavara
# Processing Record 4 of Set 10 | kahului
# Processing Record 5 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 10 | olga
# Processing Record 7 of Set 10 | tessalit
# Processing Record 8 of Set 10 | villazon
# Processing Record 9 of Set 10 | youghal
# Processing Record 10 of Set 10 | vedeno
# Processing Record 11 of Set 10 | padang
# Processing Record 12 of Set 10 | takoradi
# Processing Record 13 of Set 10 | port hardy
# Processing Record 14 of Set 10 | taltal
# Processing Record 15 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 10 | codrington
# Processing Record 17 of Set 10 | nanga eboko
# Processing Record 18 of Set 10 | sakakah
# Processing Record 19 of Set 10 | pemangkat
# Processing Record 20 of Set 10 | kedgwick
# Processing Record 21 of Set 10 | saint anthony
# Processing Record 22 of Set 10 | warri
# Processing Record 23 of Set 10 | weiser
# Processing Record 24 of Set 10 | hualmay
# Processing Record 25 of Set 10 | niteroi
# Processing Record 26 of Set 10 | qui nhon
# Processing Record 27 of Set 10 | lingao
# Processing Record 28 of Set 10 | kasane
# Processing Record 29 of Set 10 | mugur-aksy
# Processing Record 30 of Set 10 | camacha
# Processing Record 31 of Set 10 | fortuna
# Processing Record 32 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 33 of Set 10 | ponta delgada
# Processing Record 34 of Set 10 | lannion
# Processing Record 35 of Set 10 | burica
# City not found. Skipping...
# Processing Record 36 of Set 10 | tyukhtet
# Processing Record 37 of Set 10 | asfi
# Processing Record 38 of Set 10 | majene
# Processing Record 39 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 40 of Set 10 | touros
# Processing Record 41 of Set 10 | namatanai
# Processing Record 42 of Set 10 | madingou
# Processing Record 43 of Set 10 | bilma
# Processing Record 44 of Set 10 | quatre cocos
# Processing Record 45 of Set 10 | mayo
# Processing Record 46 of Set 10 | qaqortoq
# Processing Record 47 of Set 10 | innisfail
# Processing Record 48 of Set 10 | teknaf
# Processing Record 49 of Set 10 | hereford
# Processing Record 50 of Set 10 | sinnamary
# Processing Record 1 of Set 11 | manzil salim
# Processing Record 2 of Set 11 | mildura
# Processing Record 3 of Set 11 | vermilion
# Processing Record 4 of Set 11 | bilibino
# Processing Record 5 of Set 11 | homer
# Processing Record 6 of Set 11 | eslov
# Processing Record 7 of Set 11 | noumea
# Processing Record 8 of Set 11 | luderitz
# Processing Record 9 of Set 11 | riviere-au-renard
# Processing Record 10 of Set 11 | zyryanka
# Processing Record 11 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 12 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 11 | chenzhou
# Processing Record 14 of Set 11 | krasnoarmeysk
# Processing Record 15 of Set 11 | sambava
# Processing Record 16 of Set 11 | moose factory
# Processing Record 17 of Set 11 | santa isabel do rio negro
# Processing Record 18 of Set 11 | salalah
# Processing Record 19 of Set 11 | altus
# Processing Record 20 of Set 11 | suntar
# Processing Record 21 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 11 | tuatapere
# Processing Record 23 of Set 11 | benghazi
# Processing Record 24 of Set 11 | khvorostyanka
# Processing Record 25 of Set 11 | grindavik
# Processing Record 26 of Set 11 | bull savanna
# Processing Record 27 of Set 11 | niquero
# Processing Record 28 of Set 11 | iquique
# Processing Record 29 of Set 11 | ushtobe
# Processing Record 30 of Set 11 | saint george
# Processing Record 31 of Set 11 | ossora
# Processing Record 32 of Set 11 | sao miguel
# Processing Record 33 of Set 11 | rocha
# Processing Record 34 of Set 11 | beloha
# Processing Record 35 of Set 11 | svetlogorsk
# Processing Record 36 of Set 11 | tabuk
# Processing Record 37 of Set 11 | brae
# Processing Record 38 of Set 11 | naze
# Processing Record 39 of Set 11 | inderka
# Processing Record 40 of Set 11 | ambon
# Processing Record 41 of Set 11 | talas
# Processing Record 42 of Set 11 | flinders
# Processing Record 43 of Set 11 | tura
# Processing Record 44 of Set 11 | jumla
# Processing Record 45 of Set 11 | townsville
# Processing Record 46 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 11 | balkhash
# Processing Record 49 of Set 11 | novobirilyussy
# Processing Record 50 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 1 of Set 12 | wajima
# Processing Record 2 of Set 12 | port-gentil
# Processing Record 3 of Set 12 | chimbote
# Processing Record 4 of Set 12 | nanakuli
# Processing Record 5 of Set 12 | ucluelet
# Processing Record 6 of Set 12 | saint-raymond
# Processing Record 7 of Set 12 | rundu
# Processing Record 8 of Set 12 | alma
# Processing Record 9 of Set 12 | luorong
# Processing Record 10 of Set 12 | inhambane
# Processing Record 11 of Set 12 | ostrovnoy
# Processing Record 12 of Set 12 | popondetta
# Processing Record 13 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 12 | kaya
# Processing Record 15 of Set 12 | saint stephen
# Processing Record 16 of Set 12 | podyuga
# Processing Record 17 of Set 12 | acajutla
# Processing Record 18 of Set 12 | merauke
# Processing Record 19 of Set 12 | hanzhong
# Processing Record 20 of Set 12 | hovd
# Processing Record 21 of Set 12 | mehamn
# Processing Record 22 of Set 12 | palimbang
# Processing Record 23 of Set 12 | nerchinskiy zavod
# Processing Record 24 of Set 12 | fartanesti
# City not found. Skipping...
# Processing Record 25 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 12 | pangnirtung
# Processing Record 27 of Set 12 | yumen
# Processing Record 28 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 12 | sibolga
# Processing Record 30 of Set 12 | portland
# Processing Record 31 of Set 12 | baglan
# Processing Record 32 of Set 12 | verkhoyansk
# Processing Record 33 of Set 12 | belmonte
# Processing Record 34 of Set 12 | yarada
# Processing Record 35 of Set 12 | maningrida
# Processing Record 36 of Set 12 | tapikan
# Processing Record 37 of Set 12 | klyuchi
# Processing Record 38 of Set 12 | pekan
# Processing Record 39 of Set 12 | mahibadhoo
# Processing Record 40 of Set 12 | biggar
# Processing Record 41 of Set 12 | faaborg
# Processing Record 42 of Set 12 | ridgecrest
# Processing Record 43 of Set 12 | lianzhou
# Processing Record 44 of Set 12 | kuching
# Processing Record 45 of Set 12 | half moon bay
# Processing Record 46 of Set 12 | oga
# Processing Record 47 of Set 12 | puerto del rosario
# Processing Record 48 of Set 12 | mandurah
# Processing Record 49 of Set 12 | weligama
# Processing Record 50 of Set 12 | dunkirk
# Processing Record 1 of Set 13 | nisia floresta
# Processing Record 2 of Set 13 | pandan
# Processing Record 3 of Set 13 | huilong
# Processing Record 4 of Set 13 | meulaboh
# Processing Record 5 of Set 13 | izhma
# Processing Record 6 of Set 13 | xingcheng
# Processing Record 7 of Set 13 | praia
# Processing Record 8 of Set 13 | soe
# Processing Record 9 of Set 13 | tartus
# Processing Record 10 of Set 13 | hervey bay
# Processing Record 11 of Set 13 | skelleftea
# Processing Record 12 of Set 13 | dunedin
# Processing Record 13 of Set 13 | matamoros
# Processing Record 14 of Set 13 | garmsar
# Processing Record 15 of Set 13 | walvis bay
# Processing Record 16 of Set 13 | formosa do rio preto
# Processing Record 17 of Set 13 | maniitsoq
# Processing Record 18 of Set 13 | aklavik
# Processing Record 19 of Set 13 | nizhniy tsasuchey
# Processing Record 20 of Set 13 | roros
# Processing Record 21 of Set 13 | vila franca do campo
# Processing Record 22 of Set 13 | hay river
# Processing Record 23 of Set 13 | khor
# Processing Record 24 of Set 13 | linxia
# Processing Record 25 of Set 13 | yanam
# Processing Record 26 of Set 13 | buluang
# Processing Record 27 of Set 13 | lincoln
# Processing Record 28 of Set 13 | barra do garcas
# Processing Record 29 of Set 13 | osoyoos
# Processing Record 30 of Set 13 | yairipok
# Processing Record 31 of Set 13 | dryden
# Processing Record 32 of Set 13 | loudi
# Processing Record 33 of Set 13 | guadalupe y calvo
# Processing Record 34 of Set 13 | kabo
# Processing Record 35 of Set 13 | meridian
# Processing Record 36 of Set 13 | kargasok
# Processing Record 37 of Set 13 | huarmey
# Processing Record 38 of Set 13 | tecolutla
# Processing Record 39 of Set 13 | staritsa
# Processing Record 40 of Set 13 | la ronge
# Processing Record 41 of Set 13 | taoudenni
# Processing Record 42 of Set 13 | duluth
# Processing Record 43 of Set 13 | montgomery
# Processing Record 44 of Set 13 | svetlaya
# Processing Record 45 of Set 13 | duyun
# Processing Record 46 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 13 | brive-la-gaillarde
# Processing Record 48 of Set 13 | cape elizabeth
# City not found. Skipping...
# Processing Record 49 of Set 13 | makat
# Processing Record 50 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 14 | highland springs
# Processing Record 2 of Set 14 | palmer
# Processing Record 3 of Set 14 | kutum
# Processing Record 4 of Set 14 | nanortalik
# Processing Record 5 of Set 14 | shangzhi
# Processing Record 6 of Set 14 | yaring
# Processing Record 7 of Set 14 | westport
# Processing Record 8 of Set 14 | basco
# Processing Record 9 of Set 14 | verkhnevilyuysk
# Processing Record 10 of Set 14 | ronne
# Processing Record 11 of Set 14 | udachnyy
# Processing Record 12 of Set 14 | xucheng
# Processing Record 13 of Set 14 | san vicente
# Processing Record 14 of Set 14 | shubarshi
# Processing Record 15 of Set 14 | vestmanna
# Processing Record 16 of Set 14 | eureka
# Processing Record 17 of Set 14 | peniche
# Processing Record 18 of Set 14 | san borja
# Processing Record 19 of Set 14 | itoman
# Processing Record 20 of Set 14 | ancud
# Processing Record 21 of Set 14 | jian
# Processing Record 22 of Set 14 | zelenoborsk
# Processing Record 23 of Set 14 | madison
# Processing Record 24 of Set 14 | qusar
# Processing Record 25 of Set 14 | koslan
# Processing Record 26 of Set 14 | costa rica
# Processing Record 27 of Set 14 | kribi
# Processing Record 28 of Set 14 | bani walid
# Processing Record 29 of Set 14 | havoysund
# Processing Record 30 of Set 14 | mizdah
# Processing Record 31 of Set 14 | mandalgovi
# Processing Record 32 of Set 14 | ayios petros
# City not found. Skipping...
# Processing Record 33 of Set 14 | sefton
# Processing Record 34 of Set 14 | jeremoabo
# Processing Record 35 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 14 | foso
# Processing Record 37 of Set 14 | mgandu
# Processing Record 38 of Set 14 | ola
# Processing Record 39 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 14 | xinzhi
# Processing Record 41 of Set 14 | morro bay
# Processing Record 42 of Set 14 | bandarbeyla
# Processing Record 43 of Set 14 | ponazyrevo
# Processing Record 44 of Set 14 | zermatt
# Processing Record 45 of Set 14 | bathsheba
# Processing Record 46 of Set 14 | aden
# Processing Record 47 of Set 14 | anadyr
# Processing Record 48 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 14 | altay
# Processing Record 50 of Set 14 | kirkuk
# Processing Record 1 of Set 15 | oktyabrskiy
# Processing Record 2 of Set 15 | chepareria
# Processing Record 3 of Set 15 | usinsk
# Processing Record 4 of Set 15 | huanren
# Processing Record 5 of Set 15 | wencheng
# Processing Record 6 of Set 15 | apatou
# Processing Record 7 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 8 of Set 15 | tiznit
# Processing Record 9 of Set 15 | khash
# Processing Record 10 of Set 15 | rexburg
# Processing Record 11 of Set 15 | hrodna
# Processing Record 12 of Set 15 | piacabucu
# Processing Record 13 of Set 15 | ahuimanu
# Processing Record 14 of Set 15 | kangasala
# Processing Record 15 of Set 15 | srandakan
# Processing Record 16 of Set 15 | vila
# Processing Record 17 of Set 15 | campobasso
# Processing Record 18 of Set 15 | batagay
# Processing Record 19 of Set 15 | lompoc
# Processing Record 20 of Set 15 | san carlos
# Processing Record 21 of Set 15 | puerto escondido
# Processing Record 22 of Set 15 | ponezhukay
# Processing Record 23 of Set 15 | campbell river
# Processing Record 24 of Set 15 | macia
# Processing Record 25 of Set 15 | omboue
# Processing Record 26 of Set 15 | kloulklubed
# Processing Record 27 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 15 | malhador
# Processing Record 29 of Set 15 | afgoye
# City not found. Skipping...
# Processing Record 30 of Set 15 | mandal
# Processing Record 31 of Set 15 | floresta
# Processing Record 32 of Set 15 | nuuk
# Processing Record 33 of Set 15 | yerbogachen
# Processing Record 34 of Set 15 | nguru
# Processing Record 35 of Set 15 | evensk
# Processing Record 36 of Set 15 | fukue
# Processing Record 37 of Set 15 | bataipora
# Processing Record 38 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 39 of Set 15 | marsh harbour
# Processing Record 40 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 15 | aksaray
# Processing Record 42 of Set 15 | ocean city
# Processing Record 43 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 15 | dalnerechensk
# Processing Record 45 of Set 15 | tual
# Processing Record 46 of Set 15 | donji komren
# City not found. Skipping...
# Processing Record 47 of Set 15 | pondicherry
# Processing Record 48 of Set 15 | helong
# Processing Record 49 of Set 15 | college
# Processing Record 50 of Set 15 | sijunjung
# Processing Record 1 of Set 16 | sao paulo de olivenca
# Processing Record 2 of Set 16 | milingimbi
# City not found. Skipping...
# Processing Record 3 of Set 16 | chapais
# Processing Record 4 of Set 16 | ranong
# Processing Record 5 of Set 16 | acari
# Processing Record 6 of Set 16 | general roca
# Processing Record 7 of Set 16 | loa janan
# Processing Record 8 of Set 16 | payakumbuh
# Processing Record 9 of Set 16 | kaihua
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Poplar Bluff  36.7570  -90.3929     92.34        46           0
# 1          Barrow  71.2906 -156.7887     60.82        67          75
# 2  Cap Malheureux -19.9842   57.6142     70.47        66          92
# 3         Rikitea -23.1203 -134.9692     72.91        77          13
# 4       Busselton -33.6500  115.3333     54.82        63          96
# 5         Lebanon  36.2081  -86.2911     90.45        63          10
# 6            Hede  33.7681  120.2517     78.94        94          93
# 7            Chuy -33.6971  -53.4616     64.47        89          17
# 8       Fairbanks  64.8378 -147.7164     72.23        81          75
# 9          Albany  42.6001  -73.9662     82.17        35          67
#
#    Wind Speed Country                 Date      Description
# 0        1.01      US  2022-07-10 21:45:48        clear sky
# 1        4.61      US  2022-07-10 21:39:07    broken clouds
# 2        8.99      MU  2022-07-10 21:45:48  overcast clouds
# 3        3.98      PF  2022-07-10 21:45:49       few clouds
# 4        2.80      AU  2022-07-10 21:45:49  overcast clouds
# 5        9.89      US  2022-07-10 21:43:29        clear sky
# 6        3.06      CN  2022-07-10 21:45:50  overcast clouds
# 7        6.55      UY  2022-07-10 21:45:50       few clouds
# 8        1.01      US  2022-07-10 21:45:51            smoke
# 9        3.09      US  2022-07-10 21:45:06    broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Poplar Bluff      US  36.7570  -90.3929     92.34        46           0
# 1          Barrow      US  71.2906 -156.7887     60.82        67          75
# 2  Cap Malheureux      MU -19.9842   57.6142     70.47        66          92
# 3         Rikitea      PF -23.1203 -134.9692     72.91        77          13
# 4       Busselton      AU -33.6500  115.3333     54.82        63          96
# 5         Lebanon      US  36.2081  -86.2911     90.45        63          10
# 6            Hede      CN  33.7681  120.2517     78.94        94          93
# 7            Chuy      UY -33.6971  -53.4616     64.47        89          17
# 8       Fairbanks      US  64.8378 -147.7164     72.23        81          75
# 9          Albany      US  42.6001  -73.9662     82.17        35          67
#
#    Wind Speed      Description
# 0        1.01        clear sky
# 1        4.61    broken clouds
# 2        8.99  overcast clouds
# 3        3.98       few clouds
# 4        2.80  overcast clouds
# 5        9.89        clear sky
# 6        3.06  overcast clouds
# 7        6.55       few clouds
# 8        1.01            smoke
# 9        3.09    broken clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
